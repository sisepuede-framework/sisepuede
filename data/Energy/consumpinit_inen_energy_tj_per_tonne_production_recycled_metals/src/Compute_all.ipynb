# %%
import pandas as pd
#Add parent and grandparent folder to sys.path and get variable name
import os
import sys
import inspect

parentdir = os.path.abspath('..')
grandparentdir=os.path.dirname(parentdir)
ggpdir=os.path.dirname(grandparentdir)

sys.path.insert(0, parentdir)
sys.path.insert(0, grandparentdir)
sys.path.insert(0, ggpdir)

# %%
mypath=grandparentdir
consumpinit_inen_vars = sorted([f for f in os.listdir(mypath) if f.startswith('consumpinit_inen_')])
consumpinit_inen_vars
# Out:
# ['consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing',
#  'consumpinit_inen_energy_tj_per_tonne_production_cement',
#  'consumpinit_inen_energy_tj_per_tonne_production_chemicals',
#  'consumpinit_inen_energy_tj_per_tonne_production_electronics',
#  'consumpinit_inen_energy_tj_per_tonne_production_glass',
#  'consumpinit_inen_energy_tj_per_tonne_production_lime_and_carbonite',
#  'consumpinit_inen_energy_tj_per_tonne_production_metals',
#  'consumpinit_inen_energy_tj_per_tonne_production_mining',
#  'consumpinit_inen_energy_tj_per_tonne_production_paper',
#  'consumpinit_inen_energy_tj_per_tonne_production_plastic',
#  'consumpinit_inen_energy_tj_per_tonne_production_recycled_glass',
#  'consumpinit_inen_energy_tj_per_tonne_production_recycled_metals',
#  'consumpinit_inen_energy_tj_per_tonne_production_recycled_paper',
#  'consumpinit_inen_energy_tj_per_tonne_production_recycled_plastic',
# ...

# %%
#Acording to https://www.eia.gov/state/data.php?sid=LA the Share of end-sue industrial energy in 2021 was 9.3% 
#with respecto the USA total comsumption
# We will apply this share to compute the variables values as this share

df_USA=pd.read_csv('../row_data/consumpinit_inen_USA.csv')
df_USA
# Out:
#     Unnamed: 0         Nation iso_code3  Year  \
# 0            0  United States       USA  2011
# 1            1  United States       USA  2012
# 2            2  United States       USA  2013
# 3            3  United States       USA  2014
# 4            4  United States       USA  2015
# 5            5  United States       USA  2016
# 6            6  United States       USA  2017
# 7            7  United States       USA  2018
# 8            8  United States       USA  2019
# 9            9  United States       USA  2020
# 10          10  United States       USA  2021
# 11          11  United States       USA  2022
# 12          12  United States       USA  2023
# 13          13  United States       USA  2024
# 14          14  United States       USA  2025
# 15          15  United States       USA  2026
# 16          16  United States       USA  2027
# 17          17  United States       USA  2028
# 18          18  United States       USA  2029
# ...

# %%
df_Louisiana = pd.DataFrame()
df_Louisiana['iso_alpha_3']=df_USA['iso_code3']
df_Louisiana['year']=df_USA['Year']
df_Louisiana

for var in consumpinit_inen_vars:
    df_Louisiana[var]=df_USA[var]*0.093
    
df_Louisiana
# Out:
#    iso_alpha_3  year  \
# 0          USA  2011
# 1          USA  2012
# 2          USA  2013
# 3          USA  2014
# 4          USA  2015
# 5          USA  2016
# 6          USA  2017
# 7          USA  2018
# 8          USA  2019
# 9          USA  2020
# 10         USA  2021
# 11         USA  2022
# 12         USA  2023
# 13         USA  2024
# 14         USA  2025
# 15         USA  2026
# 16         USA  2027
# 17         USA  2028
# 18         USA  2029
# 19         USA  2030
# 20         USA  2031
# 21         USA  2032
# 22         USA  2033
# 23         USA  2034
# 24         USA  2035
# 25         USA  2036
# 26         USA  2037
# 27         USA  2038
# 28         USA  2039
# 29         USA  2040
# 30         USA  2041
# 31         USA  2042
# 32         USA  2043
# 33         USA  2044
# 34         USA  2045
# 35         USA  2046
# 36         USA  2047
# 37         USA  2048
# 38         USA  2049
# 39         USA  2050
#
# ...
