# %%
# Add GrandParent Folder to System Path

import os
import sys
import inspect

parentdir = os.path.abspath('..')
grandparentdir=os.path.dirname(parentdir)
sys.path.insert(0, parentdir)
sys.path.insert(0, grandparentdir)

sys.path
# Out:
# ['/Users/mateotrc/Documents/TEC/Lousiana/data/Transportation',
#  '/Users/mateotrc/Documents/TEC/Lousiana/data/Transportation/occrate_trns_passenger_per_vehicle_rail_passenger',
#  '/Users/mateotrc/opt/anaconda3/envs/sisepuede/lib/python311.zip',
#  '/Users/mateotrc/opt/anaconda3/envs/sisepuede/lib/python3.11',
#  '/Users/mateotrc/opt/anaconda3/envs/sisepuede/lib/python3.11/lib-dynload',
#  '',
#  '/Users/mateotrc/opt/anaconda3/envs/sisepuede/lib/python3.11/site-packages']

# %%
# Acording to a previous study with Eropean data, the the average rail occupacy rate is 132.5

import pandas as pd
import numpy as np

#Variable name
var_name='occrate_trns_passenger_per_vehicle_rail_passenger'
#### HISTORICAL ######
dato=132.5
years_hist=np.arange(2010,2024,1)
coun_year=[]
for year in years_hist:
    coun_year.append(['LA','louisiana',year,dato])
df_historical_out = pd.DataFrame(coun_year,columns=['iso_code3','Region', 'Year',var_name])
df_historical_out.to_csv('../input_to_sisepuede/historical/'+var_name+'.csv')
df_historical_out
# Out:
#    iso_code3     Region  Year  \
# 0         LA  louisiana  2010
# 1         LA  louisiana  2011
# 2         LA  louisiana  2012
# 3         LA  louisiana  2013
# 4         LA  louisiana  2014
# 5         LA  louisiana  2015
# 6         LA  louisiana  2016
# 7         LA  louisiana  2017
# 8         LA  louisiana  2018
# 9         LA  louisiana  2019
# 10        LA  louisiana  2020
# 11        LA  louisiana  2021
# 12        LA  louisiana  2022
# 13        LA  louisiana  2023
#
#     occrate_trns_passenger_per_vehicle_rail_passenger
# 0                                               132.5
# 1                                               132.5
# 2                                               132.5
# 3                                               132.5
# 4                                               132.5
# 5                                               132.5
# 6                                               132.5
# 7                                               132.5
# 8                                               132.5
# 9                                               132.5
# 10                                              132.5
# 11                                              132.5
# 12                                              132.5
# 13                                              132.5

# %%
#Variable name
#### projected ######
years_porj=np.arange(max(years_hist)+1,2051,1)
for year in years_porj:
    coun_year.append(['LA','louisiana',year,dato])
df_projected_out = pd.DataFrame(coun_year, columns=['iso_code3','Region', 'Year',var_name])
df_projected_out.to_csv('../input_to_sisepuede/projected/'+var_name+'.csv')
df_projected_out
# Out:
#    iso_code3     Region  Year  \
# 0         LA  louisiana  2010
# 1         LA  louisiana  2011
# 2         LA  louisiana  2012
# 3         LA  louisiana  2013
# 4         LA  louisiana  2014
# 5         LA  louisiana  2015
# 6         LA  louisiana  2016
# 7         LA  louisiana  2017
# 8         LA  louisiana  2018
# 9         LA  louisiana  2019
# 10        LA  louisiana  2020
# 11        LA  louisiana  2021
# 12        LA  louisiana  2022
# 13        LA  louisiana  2023
# 14        LA  louisiana  2024
# 15        LA  louisiana  2025
# 16        LA  louisiana  2026
# 17        LA  louisiana  2027
# 18        LA  louisiana  2028
# 19        LA  louisiana  2029
# 20        LA  louisiana  2030
# 21        LA  louisiana  2031
# 22        LA  louisiana  2032
# 23        LA  louisiana  2033
# 24        LA  louisiana  2034
# 25        LA  louisiana  2035
# 26        LA  louisiana  2036
# 27        LA  louisiana  2037
# 28        LA  louisiana  2038
# 29        LA  louisiana  2039
# 30        LA  louisiana  2040
# 31        LA  louisiana  2041
# 32        LA  louisiana  2042
# 33        LA  louisiana  2043
# 34        LA  louisiana  2044
# 35        LA  louisiana  2045
# 36        LA  louisiana  2046
# 37        LA  louisiana  2047
# 38        LA  louisiana  2048
# 39        LA  louisiana  2049
# 40        LA  louisiana  2050
#
#     occrate_trns_passenger_per_vehicle_rail_passenger
# 0                                               132.5
# 1                                               132.5
# 2                                               132.5
# 3                                               132.5
# 4                                               132.5
# 5                                               132.5
# 6                                               132.5
# 7                                               132.5
# 8                                               132.5
# 9                                               132.5
# 10                                              132.5
# 11                                              132.5
# 12                                              132.5
# 13                                              132.5
# 14                                              132.5
# 15                                              132.5
# 16                                              132.5
# 17                                              132.5
# 18                                              132.5
# 19                                              132.5
# 20                                              132.5
# 21                                              132.5
# 22                                              132.5
# 23                                              132.5
# 24                                              132.5
# 25                                              132.5
# 26                                              132.5
# 27                                              132.5
# 28                                              132.5
# 29                                              132.5
# 30                                              132.5
# 31                                              132.5
# 32                                              132.5
# 33                                              132.5
# 34                                              132.5
# 35                                              132.5
# 36                                              132.5
# 37                                              132.5
# 38                                              132.5
# 39                                              132.5
# 40                                              132.5
